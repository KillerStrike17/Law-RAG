# %%
import pandas as pd
import re

# %%
data_df = pd.read_csv('/Users/shubham.agnihotri/Documents/GitHub/Law-RAG/data.csv')
data_df.head()
# Out:
#            first_party   second_party  \
# 0             Jane Roe     Henry Wade
# 1  Peter Stanley, Sr.        Illinois
# 2         John Giglio   United States
# 3           Sally Reed     Cecil Reed
# 4        Marvin Miller     California
#
#                                                facts first_party_winner     ID
# 0  In 1970 Jane Roe a fictional name used in cour...               True  50606
# 1  Joan Stanley had three children with Peter Sta...               True  50613
# 2  John Giglio was convicted of passing forged mo...               True  50623
# 3  The Idaho Probate Code specified that males mu...               True  50632
# 4  Miller after conducting a mass mailing campaig...               True  50643

# %%
for index, row in data_df.iterrows():
    # print(index)
    data_

# %%
meta_df = pd.read_csv('/Users/shubham.agnihotri/Documents/GitHub/Law-RAG/meta_df.csv')
meta_df.head()
# Out:
#       ID                     name                                     href  \
# 0  50606              Roe v. Wade    https://api.oyez.org/cases/1971/70-18
# 1  50613      Stanley v. Illinois  https://api.oyez.org/cases/1971/70-5014
# 2  50623  Giglio v. United States    https://api.oyez.org/cases/1971/70-29
# 3  50632             Reed v. Reed     https://api.oyez.org/cases/1971/70-4
# 4  50643     Miller v. California    https://api.oyez.org/cases/1971/70-73
#
#     docket  term          first_party   second_party  majority_vote  \
# 0    70-18  1971             Jane Roe     Henry Wade              7
# 1  70-5014  1971  Peter Stanley, Sr.        Illinois              5
# 2    70-29  1971         John Giglio   United States              7
# 3     70-4  1971           Sally Reed     Cecil Reed              7
# 4    70-73  1971        Marvin Miller     California              5
#
#    minority_vote     decision_type        disposition       issue_area
# ...
